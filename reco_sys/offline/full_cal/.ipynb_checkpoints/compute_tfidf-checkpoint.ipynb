# %% [markdown]
# ### 计算TFIDF
# #### 1、先计算分词之后的每篇文章的词频，得到CV模型
# #### 2、然后根据词频计算IDF以及词，得到IDF模型

# %%
import os 
import sys
BASE_DIR = os.path.dirname(os.path.dirname(os.getcwd()))
sys.path.insert(0, os.path.join(BASE_DIR))
PYSPARK_PYTHON = "/miniconda2/envs/reco_sys/bin/python"

os.environ["PYSPARK_PYTHON"] = PYSPARK_PYTHON
os.environ["PYSPARK_DRIVER_PYTHON"] = PYSPARK_PYTHON

from offline import SparkSessionBase

class KeywordsToTfidf(SparkSessionBase):
    SPARK_APP_NAME = "keywordsByTFIDF"
    SPARK_EXECUTOR_MEMORY = "7g"
    ENABLE_HIVE_SUPPORT = True

    def __init__(self):
        self.spark = self._create_spark_session()

# %%
ktt = KeywordsToTfidf()

# %%
# 分词
def segmentation(partition):
    import os
    import re

    import jieba
    import jieba.analyse
    import jieba.posseg as pseg
    import codecs

    abspath = "/root/words"

    # 结巴加载用户词典
    userDict_path = os.path.join(abspath, "ITKeywords.txt")
    jieba.load_userdict(userDict_path)

    # 停用词文本
    stopwords_path = os.path.join(abspath, "stopwords.txt")

    def get_stopwords_list():
        """返回stopwords列表"""
        stopwords_list = [i.strip()
                          for i in codecs.open(stopwords_path).readlines()]
        return stopwords_list

    # 所有的停用词列表
    stopwords_list = get_stopwords_list()

    # 分词
    def cut_sentence(sentence):
        """对切割之后的词语进行过滤，去除停用词，保留名词，英文和自定义词库中的词，长度大于2的词"""
        # print(sentence,"*"*100)
        # eg:[pair('今天', 't'), pair('有', 'd'), pair('雾', 'n'), pair('霾', 'g')]
        seg_list = pseg.lcut(sentence)
        seg_list = [i for i in seg_list if i.flag not in stopwords_list]
        filtered_words_list = []
        for seg in seg_list:
            # print(seg)
            if len(seg.word) <= 1:
                continue
            elif seg.flag == "eng":
                if len(seg.word) <= 2:
                    continue
                else:
                    filtered_words_list.append(seg.word)
            elif seg.flag.startswith("n"):
                filtered_words_list.append(seg.word)
            elif seg.flag in ["x", "eng"]:  # 是自定一个词语或者是英文单词
                filtered_words_list.append(seg.word)
        return filtered_words_list

    for row in partition:
        sentence = re.sub("<.*?>", "", row.sentence)    # 替换掉标签数据
        words = cut_sentence(sentence)
        yield row.article_id, row.channel_id, words

# %%
ktt.spark.sql("use article")
article_dataframe = ktt.spark.sql("select * from article_data limit 20")
words_df = article_dataframe.rdd.mapPartitions(segmentation).toDF(["article_id", "channel_id", "words"])

# %%
type(article_dataframe.rdd)
# Out:
# pyspark.rdd.RDD

# %%
article_dataframe.show()
# Out:
# +----------+----------+------------+--------------------+--------------------+--------------------+
# |article_id|channel_id|channel_name|               title|             content|            sentence|
# +----------+----------+------------+--------------------+--------------------+--------------------+
# |         1|        17|          前端|     Vue props用法小结原荐|<p><strong>Vue pr...|前端,Vue props用法小结原...|
# |         2|        17|          前端|vue.js响应式原理解析与实现—...|<p>上次我们已经分析了vue.j...|前端,vue.js响应式原理解析与...|
# |         3|        17|          前端|JavaScript中浅拷贝和深拷...|<p>要理解 JavaScript...|前端,JavaScript中浅拷贝...|
# |         4|        17|          前端|基于vue2.0 +vuex+ e...|<p>效果演示地址,</p><p>...|前端,基于vue2.0 +vuex...|
# |         5|        17|          前端|immutability因Reac...|<p><img src="http...|前端,immutability因R...|
# |         6|        17|          前端|简单了解 node npm cnp...|<span id="OSC_h1_...|前端,简单了解 node npm ...|
# |         7|        17|          前端|       Web工程师以太坊入门原荐|<p>我经常构建使用以太坊的Web...|前端,Web工程师以太坊入门原荐,...|
# |         8|        17|          前端|Webpack 4 api 了解与...|<h2>webpack 最近升级到...|前端,Webpack 4 api ...|
# |         9|        17|          前端|vue中用数据驱动视图的思想去写代...|<h4>前言</h4><p>如何在...|前端,vue中用数据驱动视图的思想...|
# |        10|        17|          前端|微信小程序中如何使用WebSock...|<p>本文由腾讯云技术团队原创，感...|前端,微信小程序中如何使用WebS...|
# |        11|        17|          前端|flux架构，是我理解错了吗？记一...|<h1>flux架构，是我理解错了...|前端,flux架构，是我理解错了吗...|
# |        12|        17|          前端|合格前端第十二弹-TypeScri...|<h2>写在前面</h2><p>T...|前端,合格前端第十二弹-TypeS...|
# |        13|        17|          前端|打造专属插件之Easy Slide...|<p><img height="7...|前端,打造专属插件之Easy Sl...|
# |        14|        17|          前端|前后端分离实践：基于vue实现网站...|<blockquote><p><s...|前端,前后端分离实践：基于vue实...|
# |        15|        17|          前端|js异步ajax实现避免页面重复提交原荐|<h3>1 ajax概述</h3>...|前端,js异步ajax实现避免页面...|
# |        17|        17|          前端|JSsearch实现在购物网站输入...|<p>在篇文章里，我们主要讲解一下...|前端,JSsearch实现在购物网...|
# |        18|        17|          前端|从零开始搭建webpack+rea...|<h2>环境主要依赖版本</h2>...|前端,从零开始搭建webpack+...|
# |        19|        17|          前端|合格前端系列第九弹-前端面试那些事顶原荐|<h2>项目相关</h2><ol>...|前端,合格前端系列第九弹-前端面试...|
# |        20|        17|          前端| 总结几个关于 jQuery 用法顶原荐|<h4>有关 jquery 用法<...|前端,总结几个关于 jQuery ...|
# |        21|        17|          前端|为Bootstrap Modal添...|<p>        网上有许多给...|前端,为Bootstrap Mod...|
# +----------+----------+------------+--------------------+--------------------+--------------------+

# %%
words_df.show()
# Out:
# +----------+----------+--------------------+
# |article_id|channel_id|               words|
# +----------+----------+--------------------+
# |         1|        17|[Vue, props, 用法, ...|
# |         2|        17|[vue, 响应式, 原理, mo...|
# |         3|        17|[JavaScript, 浅拷贝,...|
# |         4|        17|[vue2, vuex, elem...|
# |         5|        17|[immutability, Re...|
# |         6|        17|[node, npm, cnpm,...|
# |         7|        17|[Web, 工程师, 以太坊, 入...|
# |         8|        17|[Web, pa, api, we...|
# |         9|        17|[vue, 中用, 数据驱动, 视...|
# |        10|        17|[程序, WebSocket, 长...|
# |        11|        17|[flux, 架构, flux, ...|
# |        12|        17|[合格, TypeScript, ...|
# |        13|        17|[专属, 插件, Easy, Sl...|
# |        14|        17|[前后端分离, vue, 网站前台...|
# |        15|        17|[ajax, 页面, 重复提交, ...|
# |        17|        17|[JSsearch, 购物网站, ...|
# |        18|        17|[web, pa, react, ...|
# |        19|        17|[合格, 事顶, 项目, 自我介绍...|
# |        20|        17|[总结, jQuery, 用法, ...|
# |        21|        17|[Bootstrap, Modal...|
# +----------+----------+--------------------+

# %% [markdown]
# ### 计算词频

# %% [markdown]
# - 只有20行的数据

# %%
# 词语与词频统计
from pyspark.ml.feature import CountVectorizer
# 总词汇的大小，文本中必须出现的次数
cv = CountVectorizer(inputCol="words", outputCol="countFeatures", vocabSize=200*10000, minDF=1.0)
# 训练词频统计模型
cv_model = cv.fit(words_df)
cv_model.write().overwrite().save("hdfs://hadoop-master:9000/headlines/models/CV.model")

# %% [markdown]
# ### 训练idf模型，保存

# %%
# 词语与词频统计
from pyspark.ml.feature import CountVectorizerModel
cv_model = CountVectorizerModel.load("hdfs://hadoop-master:9000/headlines/models/CV.model")
# 得出词频向量结果
cv_result = cv_model.transform(words_df)

# %%
# 训练IDF模型
from pyspark.ml.feature import IDF
idf = IDF(inputCol="countFeatures", outputCol="idfFeatures")
idfModel = idf.fit(cv_result)
# idfModel.write().overwrite().save("hdfs://hadoop-master:9000/headlines/models/IDF.model")

# %%
import pyspark.spark.sparkContext as sc
keywords_list_with_idf = list(zip(cv_model.vocabulary, idf_model.idf.toArray()))
def func(data):
    for index in range(len(data)):
        print(1,data)
        data[index] = list(data[index])
        data[index].append(index)
        data[index][1] = float(data[index][1])
        print(2, data)
        break;
func(keywords_list_with_idf)
# sc = spark.sparkContext
rdd = sparkContext.parallelize(keywords_list_with_idf)
df = rdd.toDF(["keywords", "idf", "index"])

# 保存
# df.write.insertInto('idf_keywords_values')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-10-495a8203c8a9> in <module>
# ----> 1 import pyspark.spark.sparkContext as sc
#       2 keywords_list_with_idf = list(zip(cv_model.vocabulary, idf_model.idf.toArray()))
#       3 def func(data):
#       4     for index in range(len(data)):
#       5         print(1,data)
#
# ModuleNotFoundError: No module named 'pyspark.spark'

# %% [markdown]
# ### 训练TFIDF模型

# %%
from pyspark.ml.feature import CountVectorizerModel
cv_model = CountVectorizerModel.load("hdfs://hadoop-master:9000/headlines/models/countVectorizerOfArticleWords.model")
from pyspark.ml.feature import IDFModel
idf_model = IDFModel.load("hdfs://hadoop-master:9000/headlines/models/IDFOfArticleWords.model")
cv_result = cv_model.transform(words_df)
tfidf_result = idf_model.transform(cv_result)


# tfidf_result的idfFeatures列,其中结构位SparseVector(length, {word_index:tfidf_fvalue})
def func(partition):
    TOPK = 20
    for row in partition:
        # 找到索引与IDF值并进行排序
        _ = list(zip(row.idfFeatures.indices, row.idfFeatures.values))
        _ = sorted(_, key=lambda x: x[1], reverse=True)
        result = _[:TOPK]
        for word_index, tfidf in result:
            yield row.article_id, row.channel_id, int(word_index), round(float(tfidf), 4)

_keywordsByTFIDF = tfidf_result.rdd.mapPartitions(func).toDF(["article_id", "channel_id", "index", "tfidf"])

# %%
cv_model.vocabulary
# Out:
# ['&#',
#  'pa',
#  'ul',
#  '代码',
#  '方法',
#  '数据',
#  'return',
#  '对象',
#  'name',
#  'this',
#  'public',
#  'int',
#  'new',
#  '问题',
#  '函数',
#  '.a',
#  'class',
#  '文件',
#  'amp',
#  'com',
#  '元素',
#  'function',
#  '用户',
#  'String',
#  '内容',
#  '时候',
#  'var',
#  '参数',
#  'for',
#  '属性',
#  '方式',
#  'void',
#  'data',
#  '__',
#  'the',
#  '技术',
#  'value',
#  '结果',
#  '信息',
#  'log',
#  '定义',
#  '类型',
#  '项目',
#  '时间',
#  'import',
#  'div',
#  '线程',
#  '系统',
#  '情况',
#  'print',
#  '节点',
#  '.h',
#  'http',
#  'self',
#  '功能',
#  'key',
#  'true',
#  'res',
#  'type',
#  'java',
#  '数组',
#  '数据库',
#  '组件',
#  '过程',
#  'console',
#  'https',
#  'index',
#  '页面',
#  '状态',
#  '程序',
#  'get',
#  'test',
#  '服务器',
#  'static',
#  'from',
#  '命令',
#  'private',
#  'else',
#  '字符串',
#  'org',
#  '模块',
#  'out',
#  '模型',
#  '总结',
#  'System',
#  '算法',
#  '目录',
#  'false',
#  '消耗',
#  'list',
#  '部分',
#  'Java',
#  '实例',
#  'www',
#  'const',
#  'root',
#  '任务',
#  'size',
#  '大家',
#  'text',
#  'url',
#  '版本',
#  '浏览器',
#  '内存',
#  'main',
#  'Python',
#  '事件',
#  '文章',
#  'user',
#  'and',
#  'string',
#  '模式',
#  '列表',
#  '图片',
#  '地址',
#  '公司',
#  '索引',
#  'let',
#  'html',
#  'println',
#  '客户端',
#  'Object',
#  '资源',
#  'width',
#  'set',
#  '网络',
#  'android',
#  '业务',
#  'php',
#  'length',
#  'web',
#  '例子',
#  'def',
#  '记录',
#  '进程',
#  '产品',
#  'app',
#  '效果',
#  'file',
#  'input',
#  'mysql',
#  '错误',
#  '框架',
#  '性能',
#  'item',
#  '链接',
#  'node',
#  '结构',
#  '消息',
#  '基础',
#  'script',
#  'python',
#  'str',
#  '标签',
#  'start',
#  '架构',
#  '工具',
#  'request',
#  '文档',
#  '无法',
#  'title',
#  'height',
#  '平台',
#  '利用',
#  'src',
#  'color',
#  'content',
#  'mod',
#  'style',
#  '基本',
#  'time',
#  'ram',
#  'next',
#  '区块链',
#  '语言',
#  'body',
#  'count',
#  'API',
#  '容器',
#  'defa',
#  'server',
#  '字段',
#  'left',
#  '路径',
#  '数字',
#  'final',
#  'JavaScript',
#  'obj',
#  'arr',
#  '环境',
#  'error',
#  '人工智能',
#  'Android',
#  'with',
#  '逻辑',
#  '目标',
#  'github',
#  'css',
#  '声明',
#  '能力',
#  '产生',
#  '场景',
#  'map',
#  '名称',
#  'context',
#  'Spring',
#  'args',
#  '关系',
#  '格式',
#  '语句',
#  'config',
#  'Thread',
#  '字符',
#  '实际',
#  'version',
#  'func',
#  'select',
#  'image',
#  'age',
#  'num',
#  '区别',
#  'state',
#  'init',
#  'table',
#  '作者',
#  '条件',
#  'Override',
#  'run',
#  'json',
#  '方案',
#  'tml',
#  '核心',
#  'object',
#  '原因',
#  'array',
#  'try',
#  '代表',
#  '手机',
#  '网站',
#  '源码',
#  '队列',
#  '空间',
#  '规则',
#  'document',
#  'not',
#  '事务',
#  '形式',
#  '协议',
#  '指向',
#  'while',
#  '数量',
#  'catch',
#  'install',
#  'NULL',
#  'err',
#  '机制',
#  'i++',
#  'view',
#  'vue',
#  '领域',
#  'List',
#  '文本',
#  'usr',
#  'end',
#  'head',
#  '企业',
#  '东西',
#  '顺序',
#  '方面',
#  'spring',
#  'code',
#  '地方',
#  '概念',
#  'len',
#  '++',
#  'target',
#  'CSS',
#  '长度',
#  '视频',
#  '插件',
#  'redis',
#  'response',
#  'img',
#  '智能',
#  'ckage',
#  'background',
#  'bin',
#  '阶段',
#  '特征',
#  '交易',
#  'method',
#  'Node',
#  'max',
#  '脚本',
#  '大量',
#  '建议',
#  'right',
#  '图像',
#  '日志',
#  'val',
#  '语法',
#  'top',
#  'springframework',
#  '布局',
#  '特性',
#  '团队',
#  '样式',
#  '原理',
#  '事情',
#  'add',
#  '标准',
#  '流程',
#  '排序',
#  'info',
#  'rent',
#  'boolean',
#  '步骤',
#  '密码',
#  'border',
#  'block',
#  '应用程序',
#  '配置文件',
#  'property',
#  'xml',
#  'etc',
#  '示例',
#  'View',
#  '范围',
#  'case',
#  'net',
#  '赋值',
#  '中国',
#  'javascript',
#  'local',
#  '软件',
#  'prototype',
#  'PHP',
#  '权限',
#  'MySQL',
#  'HTML',
#  'event',
#  'message',
#  'model',
#  'use',
#  'React',
#  'throws',
#  'che',
#  'Vue',
#  'SQL',
#  '速度',
#  'hello',
#  '编码',
#  'Linux',
#  'extends',
#  'number',
#  'break',
#  'then',
#  '开发者',
#  'window',
#  'ssword',
#  'Web',
#  '全部',
#  '部署',
#  '官方',
#  'require',
#  'create',
#  'CPU',
#  '名字',
#  'session',
#  '解决方案',
#  '动画',
#  'App',
#  'font',
#  'HTTP',
#  'URL',
#  'Promise',
#  '网页',
#  'position',
#  'line',
#  'build',
#  'Redis',
#  '市场',
#  '标记',
#  '行业',
#  'call',
#  '方向',
#  'service',
#  '策略',
#  'float',
#  'localhost',
#  'margin',
#  'msg',
#  '选项',
#  '区域',
#  'client',
#  'echo',
#  '路由',
#  'r2',
#  '动态',
#  '视图',
#  'artifactId',
#  '分类',
#  'read',
#  'hash',
#  '文件夹',
#  '机器学习',
#  '关键字',
#  'groupId',
#  '效率',
#  '全局',
#  'layout',
#  'button',
#  '机器',
#  '指令',
#  'User',
#  'long',
#  '体验',
#  'range',
#  '返回值',
#  'box',
#  'foo',
#  'Integer',
#  '游戏',
#  '模板',
#  'all',
#  'push',
#  '表达式',
#  '思路',
#  '按钮',
#  'png',
#  'super',
#  '目的',
#  'True',
#  'nginx',
#  'filter',
#  'char',
#  'that',
#  '代理',
#  '字节',
#  '指针',
#  'date',
#  '个人',
#  'close',
#  'dev',
#  'The',
#  'txt',
#  '文字',
#  'Person',
#  'update',
#  '定位',
#  'city',
#  'sql',
#  '服务端',
#  'Exception',
#  '普通',
#  '程序员',
#  'options',
#  'bean',
#  'util',
#  '传统',
#  'min',
#  'DOM',
#  'status',
#  'display',
#  '界面',
#  'Map',
#  'sum',
#  'open',
#  'resolve',
#  '高度',
#  '子类',
#  'show',
#  'find',
#  'href',
#  'where',
#  'form',
#  '数据结构',
#  '比特币',
#  'username',
#  'action',
#  'write',
#  'git',
#  'Class',
#  'dependency',
#  '集群',
#  '世界',
#  'api',
#  'conf',
#  '开源',
#  '客户',
#  '阿里',
#  'template',
#  '序列',
#  'first',
#  'element',
#  '编程',
#  'fmt',
#  'npm',
#  'socket',
#  'byte',
#  '原文',
#  'format',
#  'lang',
#  '父类',
#  'dis',
#  'throw',
#  'token',
#  'label',
#  'source',
#  '微服务',
#  '规范',
#  'toString',
#  'linux',
#  '绘制',
#  '中心',
#  'child',
#  '价值',
#  'struct',
#  '社区',
#  '成本',
#  '博客',
#  'port',
#  'None',
#  'JSON',
#  'interface',
#  'nil',
#  '课程',
#  'transform',
#  'Server',
#  'put',
#  '屏幕',
#  'ppend',
#  'cache',
#  '端口',
#  '深度学习',
#  '颜色',
#  'dding',
#  '感觉',
#  '作用域',
#  '关键',
#  'join',
#  'loader',
#  'query',
#  '教程',
#  'utf',
#  '链表',
#  '新建',
#  'googlevideo',
#  'group',
#  '#include',
#  '底层',
#  '后台',
#  'demo',
#  '特点',
#  '数据类型',
#  '单位',
#  'link',
#  'export',
#  '次数',
#  'values',
#  '字典',
#  'blog',
#  'boot',
#  '计算机',
#  '互联网',
#  'queue',
#  'lib',
#  '科技',
#  'output',
#  'callback',
#  'undefined',
#  'header',
#  'train',
#  'File',
#  '用法',
#  '经验',
#  'react',
#  'make',
#  'application',
#  '合约',
#  'temp',
#  'post',
#  'row',
#  'Array',
#  '宽度',
#  'thread',
#  'store',
#  'task',
#  'ctx',
#  'UTF',
#  '个数',
#  'props',
#  '整体',
#  'ArrayList',
#  'example',
#  '意义',
#  '答案',
#  '分布式',
#  '整数',
#  '成员',
#  'lock',
#  'meta',
#  'master',
#  '数据集',
#  'tch',
#  'Google',
#  '同学',
#  'Date',
#  'center',
#  '数值',
#  '加密',
#  'instance',
#  '细节',
#  '样本',
#  'SELECT',
#  '商品',
#  '手动',
#  '线程池',
#  '学生',
#  '篇文章',
#  'cookie',
#  'iOS',
#  'names',
#  'Math',
#  'docker',
#  'current',
#  'HashMap',
#  '关联',
#  '原生',
#  '一个对象',
#  '意思',
#  'render',
#  'home',
#  '人类',
#  'flex',
#  'using',
#  '距离',
#  'auto',
#  '命名',
#  '优势',
#  '背景',
#  '神经网络',
#  '主题',
#  'random',
#  'bind',
#  'canvas',
#  '处理器',
#  'one',
#  'Hello',
#  '缺点',
#  'you',
#  'protected',
#  '符号',
#  'red',
#  '入门',
#  '消费者',
#  'process',
#  '概率',
#  'plugin',
#  'rams',
#  '案例',
#  '级别',
#  '选择器',
#  'insert',
#  'tar',
#  '腾讯',
#  'env',
#  '有点',
#  'click',
#  '百度',
#  'match',
#  '重点',
#  'router',
#  'dict',
#  'double',
#  'equals',
#  '引擎',
#  '工程',
#  'Activity',
#  'tmp',
#  'delete',
#  'sudo',
#  '机器人',
#  'are',
#  '原型',
#  '编辑',
#  'constructor',
#  'option',
#  'synchronized',
#  'Windows',
#  'JVM',
#  '全球',
#  'alert',
#  'servlet',
#  '朋友',
#  '计划',
#  '程度',
#  'C++',
#  'remove',
#  'pre',
#  '编译器',
#  '运行时',
#  'base',
#  'host',
#  'last',
#  '标题',
#  '结点',
#  'dir',
#  '水平',
#  '实例化',
#  'getName',
#  '生命周期',
#  '角度',
#  'article',
#  'order',
#  'async',
#  '静态',
#  'core',
#  '哈希',
#  'align',
#  'handler',
#  '常量',
#  'load',
#  '角色',
#  '优点',
#  'split',
#  '像素',
#  'jpg',
#  'APP',
#  '回调函数',
#  '价格',
#  'FROM',
#  'location',
#  '流量',
#  '区块',
#  '控件',
#  'bool',
#  'implements',
#  'False',
#  'save',
#  'items',
#  '人员',
#  '分支',
#  'jQuery',
#  'std',
#  'Set',
#  'bar',
#  'Test',
#  '闭包',
#  'Service',
#  '硬件',
#  '办法',
#  '本质',
#  '电脑',
#  '小时',
#  'buffer',
#  '磁盘',
#  '分区',
#  'xxx',
#  'bottom',
#  'sleep',
#  'jar',
#  'GET',
#  '矩阵',
#  '苹果',
#  '信号',
#  'wait',
#  'channel',
#  'proxy',
#  'Student',
#  'address',
#  '大数据',
#  '实体',
#  'tcp',
#  'login',
#  'none',
#  '专业',
#  '爬虫',
#  'setTimeout',
#  '资料',
#  'can',
#  '入口',
#  'container',
#  '原则',
#  '内核',
#  'charset',
#  '单词',
#  'now',
#  'Type',
#  'column',
#  'encoding',
#  '空格',
#  'score',
#  'replace',
#  'filename',
#  'await',
#  '机会',
#  'ref',
#  '工程师',
#  'send',
#  '交流',
#  '二进制',
#  '美国',
#  'component',
#  'sort',
#  '时代',
#  '中间件',
#  '镜像',
#  '思想',
#  'keys',
#  '人们',
#  '容量',
#  'IOException',
#  'TCP',
#  '终端',
#  'mode',
#  '深度',
#  'printStackTrace',
#  'before',
#  '用户名',
#  '动作',
#  'sys',
#  'promise',
#  '内置',
#  'tag',
#  '谷歌',
#  'flag',
#  '评论',
#  'schema',
#  'plt',
#  '表单',
#  '理论',
#  '装饰',
#  '官网',
#  '嵌套',
#  'Context',
#  'copy',
#  '小米',
#  'entry',
#  '域名',
#  '调度',
#  '备份',
#  'search',
#  'scope',
#  '以太坊',
#  'person',
#  'req',
#  'typeof',
#  'will',
#  '序列化',
#  'word',
#  '订单',
#  'conn',
#  'POST',
#  '区分',
#  'Error',
#  'reject',
#  'via',
#  '历史',
#  'timeout',
#  'h2',
#  '权重',
#  '文件名',
#  '证明',
#  '老师',
#  'Println',
#  'world',
#  'btn',
#  '整理',
#  '向量',
#  'bytes',
#  'tree',
#  'rse',
#  'files',
#  'properties',
#  '孩子',
#  'yum',
#  'tab',
#  '命令行',
#  '论文',
#  '来源',
#  '账户',
#  '知识点',
#  'ret',
#  'printf',
#  'after',
#  'Name',
#  'success',
#  'Session',
#  'ES6',
#  'shape',
#  '源代码',
#  '公众号',
#  'total',
#  'system',
#  '华为',
#  'field',
#  '尺寸',
#  '金融',
#  '风险',
#  '表格',
#  'student',
#  '中文',
#  '风格',
#  'commit',
#  '标识',
#  'project',
#  'baidu',
#  '城市',
#  '运算符',
#  'inline',
#  'yield',
#  '全面',
#  'images',
#  '拷贝',
#  'fun',
#  'connection',
#  '技巧',
#  'Docker',
#  'admin',
#  'cout',
#  '仓库',
#  '字体',
#  'author',
#  'maven',
#  'debug',
#  'stack',
#  '属性值',
#  'include',
#  'offset',
#  '构造方法',
#  'This',
#  'Data',
#  'iPhone',
#  '类别',
#  '设计模式',
#  '联系',
#  '体系',
#  'jianshu',
#  '2d',
#  '中断',
#  'connect',
#  'arguments',
#  '开发人员',
#  'Log',
#  'Bean',
#  'Model',
#  'Component',
#  'solid',
#  'exports',
#  '迭代器',
#  'logger',
#  'support',
#  'dom',
#  '一致性',
#  '明白',
#  'XML',
#  'users',
#  'global',
#  '员工',
#  '两者',
#  '专门',
#  'cat',
#  'Chrome',
#  '规定',
#  '省略',
#  'DEFAULT',
#  'price',
#  'worker',
#  'grid',
#  '习惯',
#  'pop',
#  'execute',
#  'into',
#  'INSERT',
#  '前言',
#  'volatile',
#  '经历',
#  '维度',
#  '笔记',
#  'Cookie',
#  '单元',
#  'command',
#  'abc',
#  'xmlns',
#  'has',
#  '读者',
#  '基本上',
#  '校验',
#  '质量',
#  'Content',
#  'level',
#  '国家',
#  '物理',
#  'stop',
#  '上线',
#  'Boot',
#  '##',
#  'finally',
#  '层面',
#  ...]

# %%
idf_model.idf.toArray()
# Out:
# array([ 1.41782959,  0.66513853,  0.80705912, ..., 11.14699352,
#        11.14699352, 11.14699352])

# %%
_keywordsByTFIDF.show()
# Out:
# +----------+----------+------+--------+
# |article_id|channel_id| index|   tfidf|
# +----------+----------+------+--------+
# |         1|        17| 96675|256.3809|
# |         1|        17|115370|200.6459|
# |         1|        17|   515|174.1541|
# |         1|        17| 20134|141.6573|
# |         1|        17|   591|126.9896|
# |         1|        17|    62|125.4149|
# |         1|        17|    45|101.2453|
# |         1|        17|   391| 85.5727|
# |         1|        17|   491| 56.6656|
# |         1|        17|  5650| 51.6382|
# |         1|        17|  1465| 37.7835|
# |         1|        17|415962|  33.441|
# |         1|        17|426351|  33.441|
# |         1|        17|   347| 31.9532|
# |         1|        17|151480| 28.0657|
# |         1|        17|   314| 26.1522|
# |         1|        17|  1353| 25.2814|
# |         1|        17|  5808|  23.998|
# |         1|        17|     5| 23.4382|
# |         1|        17|    28| 22.5731|
# +----------+----------+------+--------+
# only showing top 20 rows

# %%
cv_result.show()
# Out:
# +----------+----------+--------------------+--------------------+
# |article_id|channel_id|               words|       countFeatures|
# +----------+----------+--------------------+--------------------+
# |         1|        17|[Vue, props, 用法, ...|(1234544,[1,2,3,5...|
# |         2|        17|[vue, 响应式, 原理, mo...|(1234544,[1,2,3,4...|
# |         3|        17|[JavaScript, 浅拷贝,...|(1234544,[0,1,2,4...|
# |         4|        17|[vue2, vuex, elem...|(1234544,[1,2,4,5...|
# |         5|        17|[immutability, Re...|(1234544,[1,2,4,5...|
# |         6|        17|[node, npm, cnpm,...|(1234544,[0,1,2,3...|
# |         7|        17|[Web, 工程师, 以太坊, 入...|(1234544,[1,2,3,4...|
# |         8|        17|[Web, pa, api, we...|(1234544,[1,2,3,1...|
# |         9|        17|[vue, 中用, 数据驱动, 视...|(1234544,[1,3,4,5...|
# |        10|        17|[程序, WebSocket, 长...|(1234544,[1,3,7,9...|
# |        11|        17|[flux, 架构, flux, ...|(1234544,[1,4,5,6...|
# |        12|        17|[合格, TypeScript, ...|(1234544,[1,2,3,4...|
# |        13|        17|[专属, 插件, Easy, Sl...|(1234544,[1,2,4,6...|
# |        14|        17|[前后端分离, vue, 网站前台...|(1234544,[1,2,3,6...|
# |        15|        17|[ajax, 页面, 重复提交, ...|(1234544,[1,2,3,4...|
# |        17|        17|[JSsearch, 购物网站, ...|(1234544,[1,2,3,4...|
# |        18|        17|[web, pa, react, ...|(1234544,[1,2,3,8...|
# |        19|        17|[合格, 事顶, 项目, 自我介绍...|(1234544,[1,2,3,4...|
# |        20|        17|[总结, jQuery, 用法, ...|(1234544,[1,2,3,4...|
# |        21|        17|[Bootstrap, Modal...|(1234544,[1,2,3,4...|
# +----------+----------+--------------------+--------------------+

# %%
# 测试tfidf_result的属性
print(type(tfidf_result))
df_tfidf_result = tfidf_result.toPandas()
len(list(df_tfidf_result.idfFeatures[0]))
# Out:
# <class 'pyspark.sql.dataframe.DataFrame'>
# 1234544

# %%
# 利用结果索引与”idf_keywords_values“合并词 
keywordsIndex = ktt.spark.sql("select keyword, index idx from idf_keywords_values")
# 利用结果索引与”idf_keywords_values“合并词
keywordsByTFIDF = _keywordsByTFIDF.join(keywordsIndex, keywordsIndex.idx == _keywordsByTFIDF.index).select(["article_id", "channel_id", "keyword", "tfidf"])
# keywordsByTFIDF.write.insertInto("tfidf_keywords_values")

# %%
keywordsByTFIDF.show()
# Out:
# +----------+----------+---------+--------+
# |article_id|channel_id|  keyword|   tfidf|
# +----------+----------+---------+--------+
# |         3|        17|      var| 22.4813|
# |         7|        17|      var| 41.2158|
# |        13|        17|      var| 74.9377|
# |        21|        17|      var| 14.9875|
# |        11|        17|  Actions| 98.2025|
# |        13|        17|barNumber|  55.735|
# |        18|        17|   loader|125.6564|
# |         7|        17|     uint| 29.6332|
# |         3|        17|      堆内存|  9.8193|
# |        17|        17| document| 16.8342|
# |         9|        17|  caidan2| 10.7415|
# |         3|        17|       &#| 41.1171|
# |        12|        17|    Watch| 42.4374|
# |        20|        17|  closest| 33.8248|
# |         4|        17|      cmd| 15.7818|
# |        10|        17|       石头| 44.6937|
# |        18|        17|      mod| 42.2456|
# |         2|        17|     元素节点|  83.279|
# |        20|        17|     提交表单|  27.922|
# |         1|        17|      Vue| 31.9532|
# +----------+----------+---------+--------+
# only showing top 20 rows

# %% [markdown]
# ### TextRank

# %%
def textrank(partition):
    import os

    import jieba
    import jieba.analyse
    import jieba.posseg as pseg
    import codecs

    abspath = "/root/words"

    # 结巴加载用户词典
    userDict_path = os.path.join(abspath, "ITKeywords.txt")
    jieba.load_userdict(userDict_path)

    # 停用词文本
    stopwords_path = os.path.join(abspath, "stopwords.txt")

    def get_stopwords_list():
        """返回stopwords列表"""
        stopwords_list = [i.strip()
                          for i in codecs.open(stopwords_path).readlines()]
        return stopwords_list

    # 所有的停用词列表
    stopwords_list = get_stopwords_list()

    class TextRank(jieba.analyse.TextRank):
        def __init__(self, window=20, word_min_len=2):
            super(TextRank, self).__init__()
            self.span = window  # 窗口大小
            self.word_min_len = word_min_len  # 单词的最小长度
            # 要保留的词性，根据jieba github ，具体参见https://github.com/baidu/lac
            self.pos_filt = frozenset(
                ('n', 'x', 'eng', 'f', 's', 't', 'nr', 'ns', 'nt', "nw", "nz", "PER", "LOC", "ORG"))

        def pairfilter(self, wp):
            """过滤条件，返回True或者False"""

            if wp.flag == "eng":
                if len(wp.word) <= 2:
                    return False

            if wp.flag in self.pos_filt and len(wp.word.strip()) >= self.word_min_len \
                    and wp.word.lower() not in stopwords_list:
                return True
    # TextRank过滤窗口大小为5，单词最小为2
    textrank_model = TextRank(window=5, word_min_len=2)
    allowPOS = ('n', "x", 'eng', 'nr', 'ns', 'nt', "nw", "nz", "c")

    for row in partition:
        tags = textrank_model.textrank(row.sentence, topK=20, withWeight=True, allowPOS=allowPOS, withFlag=False)
        for tag in tags:
            yield row.article_id, row.channel_id, tag[0], tag[1]

# %%
# 计算TextRank
textrank_keywords_df = article_dataframe.rdd.mapPartitions(textrank).toDF(
["article_id", "channel_id", "keyword", "textrank"])

# textrank_keywords_df.write.insertInto("textrank_keywords_values")

# %%
textrank_keywords_df.show()
# Out:
# +----------+----------+-----------+-------------------+
# |article_id|channel_id|    keyword|           textrank|
# +----------+----------+-----------+-------------------+
# |         1|        17|         组件|                1.0|
# |         1|        17|      props| 0.5154370285370792|
# |         1|        17|        msg| 0.4702870805040915|
# |         1|        17|         数据|0.45582871346014814|
# |         1|        17|      child|0.31296871088663686|
# |         1|        17|     strong| 0.3089686862986876|
# |         1|        17|       code| 0.3032954542098871|
# |         1|        17|        Vue|0.24087919593391022|
# |         1|        17|         pa|0.22048638072881815|
# |         1|        17|         ul| 0.2018632319447092|
# |         1|        17|  childNode|0.19610401758526286|
# |         1|        17|     String|0.17134793062324802|
# |         1|        17|forChildMsg| 0.1668240799844303|
# |         1|        17|       defa| 0.1655549274585362|
# |         1|        17|        pre|0.15524657279047274|
# |         1|        17|  validator|0.15421576195324882|
# |         1|        17|         属性|0.15197896394191618|
# |         1|        17|         定义|0.14652996142104396|
# |         1|        17|       函数返回|0.14198051680758564|
# |         1|        17|         函数|0.14138761520330873|
# +----------+----------+-----------+-------------------+
# only showing top 20 rows

# %% [markdown]
# ### 文章画像结果

# %%
idf = ktt.spark.sql("select * from idf_keywords_values")
idf = idf.withColumnRenamed("keyword", "keyword1")
result = textrank_keywords_df.join(idf,textrank_keywords_df.keyword==idf.keyword1)
keywords_res = result.withColumn("weights", result.textrank * result.idf).select(["article_id", "channel_id", "keyword", "weights"])

# %%
result.show()
# Out:
# +----------+----------+---------+-------------------+---------+------------------+------+
# |article_id|channel_id|  keyword|           textrank| keyword1|               idf| index|
# +----------+----------+---------+-------------------+---------+------------------+------+
# |         2|        17|    input|  0.298715457651815|    input|2.5936612831652797|   139|
# |         1|        17|childNode|0.19610401758526286|childNode| 7.869848788205214| 20134|
# |        12|        17|   import| 0.2446905384177029|   import|1.9502451027406746|    44|
# |        10|        17|      amp| 0.6220890404292903|      amp|1.5313880611157102|    18|
# |        12|        17|      amp| 0.1938349932225792|      amp|1.5313880611157102|    18|
# |        13|        17|      amp| 0.2704438727699735|      amp|1.5313880611157102|    18|
# |        20|        17| dragsort|0.19898628640236093| dragsort|10.741528413089226|153844|
# |         3|        17|      jpg| 0.5186416300247046|      jpg| 3.486643603011888|   727|
# |         4|        17|      jpg| 0.6375793153425262|      jpg| 3.486643603011888|   727|
# |         6|        17|      jpg|0.40989436301426946|      jpg| 3.486643603011888|   727|
# |         8|        17|      jpg| 0.2585599047952723|      jpg| 3.486643603011888|   727|
# |         2|        17|  textReg|0.29488918445113477|  textReg|10.741528413089226| 95140|
# |        11|        17|       事件| 0.3617957860287148|       事件|2.2787914074690474|   106|
# |        20|        17|       事件| 0.5163203257622567|       事件|2.2787914074690474|   106|
# |        20|        17|       h5|                1.0|       h5| 4.757592132402036|  2503|
# |         2|        17| fragment| 0.6411543089793412| fragment| 5.377111244836666|  2540|
# |         4|        17|       文件| 0.3439242393759173|       文件|1.2163286406564702|    17|
# |        18|        17|       文件| 0.5402034553754704|       文件|1.2163286406564702|    17|
# |        17|        17|  uploads| 0.5514700564213674|  uploads| 6.205351098588086| 10676|
# |         4|        17|      文件夹|0.47560430908492035|      文件夹|2.7398384349900904|   404|
# +----------+----------+---------+-------------------+---------+------------------+------+
# only showing top 20 rows

# %%
keywords_res.show()
# Out:
# +----------+----------+---------+-------------------+
# |article_id|channel_id|  keyword|            weights|
# +----------+----------+---------+-------------------+
# |         2|        17|    input| 0.7747667171945103|
# |         1|        17|childNode|  1.543308965155555|
# |        12|        17|   import|  0.477206524236104|
# |        10|        17|      amp| 0.9526597294643435|
# |        12|        17|      amp| 0.2968365944475024|
# |        13|        17|      amp|0.41415451796183356|
# |        20|        17| dragsort| 2.1374168492060703|
# |         3|        17|      jpg| 1.8083185215812947|
# |         4|        17|      jpg|  2.223011841251718|
# |         6|        17|      jpg| 1.4291555587143352|
# |         8|        17|      jpg| 0.9015062380497989|
# |         2|        17|  textReg| 3.1675605534945737|
# |        11|        17|       事件| 0.8244571284607454|
# |        20|        17|       事件|   1.17658632184865|
# |        20|        17|       h5|  4.757592132402036|
# |         2|        17| fragment|  3.447558044488298|
# |         4|        17|       文件|0.41832490256891997|
# |        18|        17|       文件| 0.6570649345547741|
# |        17|        17|  uploads|  3.422065320452766|
# |         4|        17|      文件夹| 1.3030789658777715|
# +----------+----------+---------+-------------------+
# only showing top 20 rows

# %%
keywords_res.registerTempTable("temptable")
merge_keywords = ktt.spark.sql("select article_id, min(channel_id) channel_id, collect_list(keyword) keywords, collect_list(weights) weights from temptable group by article_id")

# 合并关键词权重合并成字典
def _func(row):
    return row.article_id, row.channel_id, dict(zip(row.keywords, row.weights))

keywords_info = merge_keywords.rdd.map(_func).toDF(["article_id", "channel_id", "keywords"])

# %%
keywords_info.show()
# Out:
# +----------+----------+--------------------+
# |article_id|channel_id|            keywords|
# +----------+----------+--------------------+
# |        19|        17|Map(pre -> 1.4355...|
# |         7|        17|Map(pre -> 1.1325...|
# |         6|        17|Map(pre -> 1.2026...|
# |         9|        17|Map(pre -> 1.4452...|
# |        17|        17|Map(static -> 1.1...|
# |         5|        17|Map(pre -> 0.8062...|
# |         1|        17|Map(pre -> 0.5692...|
# |        10|        17|Map(源码 -> 1.08268...|
# |         3|        17|Map(对象 -> 1.04255...|
# |        12|        17|Map(pre -> 1.0007...|
# |         8|        17|Map(pre -> 1.2047...|
# |        11|        17|Map(pre -> 1.4338...|
# |         2|        17|Map(test -> 0.711...|
# |         4|        17|Map(jpg -> 2.2230...|
# |        13|        17|Map(border -> 0.8...|
# |        18|        17|Map(pre -> 0.7541...|
# |        14|        17|Map(角色 -> 1.48177...|
# |        21|        17|Map(modal -> 6.13...|
# |        15|        17|Map(window -> 1.3...|
# |        20|        17|Map(pre -> 1.7561...|
# +----------+----------+--------------------+

# %%
keywords_info.toPandas()

# %%
topic_sql = '''
    select t.article_id aid, collect_set(t.keyword) topics from tfidf_keywords_values  t
    inner join 
    textrank_keywords_values r
    where t.keyword = r.keyword
    group by aid
'''

article_topics = ktt.spark.sql(topic_sql)

# %%
article_topics.show()
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/miniconda2/envs/reco_sys/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3267, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-29-3fb2161d0a43>", line 1, in <module>
#     article_topics.show()
#   File "/miniconda2/envs/reco_sys/lib/python3.6/site-packages/pyspark/sql/dataframe.py", line 336, in show
#     print(self._jdf.showString(n, 20))
#   File "/miniconda2/envs/reco_sys/lib/python3.6/site-packages/py4j/java_gateway.py", line 1255, in __call__
#     answer = self.gateway_client.send_command(command)
#   File "/miniconda2/envs/reco_sys/lib/python3.6/site-packages/py4j/java_gateway.py", line 985, in send_command
#     response = connection.send_command(command)
#   File "/miniconda2/envs/reco_sys/lib/python3.6/site-packages/py4j/java_gateway.py", line 1152, in send_command
#     answer = smart_decode(self.stream.readline()[:-1])
#   File "/miniconda2/envs/reco_sys/lib/python3.6/socket.py", line 586, in readinto
#     return self._sock.recv_into(b)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/miniconda2/envs/reco_sys/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2018, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/miniconda2/envs/reco_sys/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1095, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/miniconda2/envs/reco_sys/lib/python3.6/site-packages/IPython/core/ultratb.py", line 313, in wrapped
#     return f(*args, **kwargs)
#   File "/miniconda2/envs/reco_sys/lib/python3.6/site-packages/IPython/core/ultratb.py", line 347, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/miniconda2/envs/reco_sys/lib/python3.6/inspect.py", line 1488, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/miniconda2/envs/reco_sys/lib/python3.6/inspect.py", line 1450, in getframeinfo
#     lines, lnum = findsource(frame)
#   File "/miniconda2/envs/reco_sys/lib/python3.6/site-packages/IPython/core/ultratb.py", line 179, in findsource
#     lines = linecache.getlines(file, globals_dict)
#   File "/miniconda2/envs/reco_sys/lib/python3.6/linecache.py", line 47, in getlines
#     return updatecache(filename, module_globals)
#   File "/miniconda2/envs/reco_sys/lib/python3.6/linecache.py", line 136, in updatecache
#     with tokenize.open(fullname) as fp:
#   File "/miniconda2/envs/reco_sys/lib/python3.6/tokenize.py", line 454, in open
#     encoding, lines = detect_encoding(buffer.readline)
#   File "/miniconda2/envs/reco_sys/lib/python3.6/tokenize.py", line 423, in detect_encoding
#     first = read_or_stop()
#   File "/miniconda2/envs/reco_sys/lib/python3.6/tokenize.py", line 381, in read_or_stop
#     return readline()
# KeyboardInterrupt
# ---------------------------------------------------------------------------
